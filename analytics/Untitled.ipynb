# %%
import pandas as pd

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (16, 7)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=pd.read_csv("/home/sampad/Desktop/rbcdata/reflowoven_vaf.csv")

# %%
data.tail()
# Out:
#       datatype                   timestamp dataunit  \
# 35540  current  2018-01-30T05:24:57.186478     Amps
# 35541  current  2018-01-30T05:24:58.290929     Amps
# 35542  current  2018-01-30T05:24:59.409409     Amps
# 35543  current  2018-01-30T05:25:00.515345     Amps
# 35544  current  2018-01-30T05:25:01.635529     Amps
#
#                    data.timestamp  data.gz  data.gy  data.gx  data.ay  \
# 35540  2018-01-30T05:24:57.186478      NaN      NaN      NaN      NaN
# 35541  2018-01-30T05:24:58.290929      NaN      NaN      NaN      NaN
# 35542  2018-01-30T05:24:59.409409      NaN      NaN      NaN      NaN
# 35543  2018-01-30T05:25:00.515345      NaN      NaN      NaN      NaN
# 35544  2018-01-30T05:25:01.635529      NaN      NaN      NaN      NaN
#
#        data.ax  data.az        deviceid  data.A1  data.A3  data.A2  \
# 35540      NaN      NaN  reflowoven_vaf    20.97    11.90    16.52
# 35541      NaN      NaN  reflowoven_vaf    22.16    13.13    17.00
# 35542      NaN      NaN  reflowoven_vaf    18.19    10.64    13.44
# 35543      NaN      NaN  reflowoven_vaf    24.53    12.05    18.63
# 35544      NaN      NaN  reflowoven_vaf    22.02    15.44    16.09
#
#        data.proximity  data.temperature  data.tempgood
# 35540             NaN               NaN            NaN
# 35541             NaN               NaN            NaN
# 35542             NaN               NaN            NaN
# 35543             NaN               NaN            NaN
# 35544             NaN               NaN            NaN

# %%
data[["timestamp"]].head()

# %%
x=data[["timestamp","data.A1"]]
x["ts"]=pd.to_datetime(x["timestamp"])
#x=x.drop(columns=["timestamp"])
x=x.set_index("ts")
x=x.tz_localize('UTC').tz_convert('Asia/Kolkata')
# Out:
# /home/sampad/Desktop/RBCCPS/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
x.plot()

# %%
ES_INDEX_DATE="2018-01-30"
dformat= ES_INDEX_DATE + " %s:%s"
_hour=9
_startmins = "00:00"
_endmins = "59:59"

# %%
x.loc[dformat%(_hour,_startmins):dformat%(_hour,_endmins)].plot()
