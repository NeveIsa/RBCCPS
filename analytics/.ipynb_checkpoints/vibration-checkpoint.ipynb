# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#ES_INDEX_DATE="2018-01-28"
ES_INDEX_DATE="2018-01-30"
ES_INDEX_DATE="2018-02-03"
DATA_FILE="../../rbcdata/%s/spv" % ES_INDEX_DATE

# %%
#%matplotlib inline
#import mpld3
#mpld3.enable_notebook()

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (16, 7)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=pd.read_csv(DATA_FILE)

# %%
section=75*60*60*48

# %%
temp=data.head(section)
#temp.head()
temp["ts"]=pd.to_datetime(temp["timestamp"])
temp=temp.set_index("ts")
temp=temp.tz_localize('UTC').tz_convert('Asia/Kolkata')
# Out:
# /home/sampad/Desktop/RBCCPS/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
temp.loc[:,"acc"]= np.sqrt(temp["data.ax"]**2 + temp["data.az"]**2)

# %%
temp[["data.ax","data.az","acc"]].plot()

# %%
temp[["data.ay"]].plot()

# %%
try:
    temp=temp.drop(columns=["timestamp","data.gx","data.gy","data.gz","data.ax","data.ay","data.az"])
except:
    temp=temp.drop(columns=["timestamp","data.ax","data.ay","data.az","data.A1","data.A2","data.A3"])

# %%
#temp=temp.head(75*60*60)
temp.plot()

# %%
x=temp.rolling(75*15).std()

# %%
x.plot()

# %%
if ES_INDEX_DATE=="2018-02-02":
    thresholdVal=0.003
elif ES_INDEX_DATE=="2018-02-03":
    thresholdVal=0.0035
else:
    thresholdVal=0.0035
x['acc_clipped'] = np.where(x['acc']>=thresholdVal, 1,0)

# %%
x["acc_clipped"].plot()

# %%
x['change'] = x['acc_clipped'] - x['acc_clipped'].shift(1)
x['change'] = np.where(x['change']>0, 1,0)

# %%
x["change"].plot()

# %%
y=x[["change"]]

# %%
z=y.cumsum()

# %%
z.plot()

# %%
y.change.sum()
# Out:
# 741

# %%
dformat= ES_INDEX_DATE + " %s:%s"
npcb=[]
for hr in range(0,24):
    start=dformat%(hr,"00:00")
    end=dformat%(hr,"59:59")
    zz=y.loc[start:end]
    ww=zz.change.sum()
    #print ww
    npcb.append(ww)
    print [hr,ww],

print "\n"
print "TOTAL--->",sum(npcb)
disection=y.loc[dformat%("00","00:00"):dformat%("23","59:59")]
print disection.change.sum()
# Out:
# [0, 43] [1, 42] [2, 34] [3, 38] [4, 40] [5, 7] [6, 20] [7, 13] [8, 39] [9, 37] [10, 35] [11, 17] [12, 37] [13, 48] [14, 38] [15, 41] [16, 37] [17, 9] [18, 23] [19, 4] [20, 30] [21, 27] [22, 47] [23, 35]
#
# TOTAL---> 741
# 741

# %%
ax=pd.Series(npcb).plot.bar(grid=True)
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    if i.get_height():
      ax.text(i.get_x(), i.get_height()+0.5, i.get_height() ,fontsize=20,color='black')

# %%
_hour=0
_startmins = "00:00"
_endmins = "59:59"

# %%
x.loc[dformat%(_hour,_startmins):dformat%(_hour,_endmins)].acc.plot()

# %%
x.acc_clipped.loc[dformat%(_hour,_startmins):dformat%(_hour,_endmins)].plot()

# %%
x.change.loc[dformat%(_hour,_startmins):dformat%(_hour,_endmins)].plot()

# %%
x.change.loc[dformat%(_hour,_startmins):dformat%(_hour,_endmins)].cumsum().plot()

# %%
temp[["data.ax","data.ay","data.ay"]].loc[dformat%(_hour,_startmins):dformat%(_hour,_endmins)].plot()

# %%
#Time PER PCB

# %%
pcbTime = x.loc[x.change==1]

# %%
pcbTime["timestamp"]=pcbTime.index
# Out:
# /home/sampad/Desktop/RBCCPS/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(pcbTime)
# Out:
# 741

# %%
pcbTime.timestamp.diff().mean()
# Out:
# Timedelta('0 days 00:01:56.714842')

# %%
pcbTime.timestamp.diff().std()
# Out:
# Timedelta('0 days 00:04:11.818123')
